# %%
import manim as mn
from manim import *

config.media_width = "75%"
config.verbosity = "WARNING"

print(mn.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import manim as mn
#       2 from manim import *
# ----> 4 config.media_width = "75%"
#       5 config.verbosity = "WARNING"
#       7 print(mn.__version__)
#
# NameError: name 'config' is not defined
